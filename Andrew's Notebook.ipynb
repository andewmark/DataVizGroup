# %%
# %pip install "altair"
# %pip install "altair_viewer"
# %pip install "pandas"
# Out:
# Requirement already satisfied: altair in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (5.5.0)
# Requirement already satisfied: jinja2 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair) (1.24.0)
# Requirement already satisfied: packaging in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair) (4.12.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from jsonschema>=3.0->altair) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from jsonschema>=3.0->altair) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from jsonschema>=3.0->altair) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from jsonschema>=3.0->altair) (0.22.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from jinja2->altair) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: altair_viewer in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (0.4.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: altair in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair_viewer) (5.5.0)
# Requirement already satisfied: altair-data-server>=0.4.0 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair_viewer) (0.4.1)
# Requirement already satisfied: portpicker in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair-data-server>=0.4.0->altair_viewer) (1.6.0)
# Requirement already satisfied: tornado in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair-data-server>=0.4.0->altair_viewer) (6.4.2)
# Requirement already satisfied: jinja2 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair->altair_viewer) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair->altair_viewer) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair->altair_viewer) (1.24.0)
# Requirement already satisfied: packaging in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair->altair_viewer) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from altair->altair_viewer) (4.12.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from jsonschema>=3.0->altair->altair_viewer) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from jsonschema>=3.0->altair->altair_viewer) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from jsonschema>=3.0->altair->altair_viewer) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from jsonschema>=3.0->altair->altair_viewer) (0.22.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from jinja2->altair->altair_viewer) (3.0.2)
# Requirement already satisfied: psutil in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from portpicker->altair-data-server>=0.4.0->altair_viewer) (6.1.1)
# Requirement already satisfied: pandas in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\princ\documents\spring 2025\cis 400 - data\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import altair as alt

alt.data_transformers.disable_max_rows()

data = pd.read_csv("environment-raw-2021.csv", skiprows=3)

# %% [markdown]
# How does deforestation impact CO₂ emissions over time? - Let's focus on the United States first

# %%
CO2_US_emissions = data[data['Indicator Name'] == 'Total greenhouse gas emissions (kt of CO2 equivalent)']
CO2_US_emissions = CO2_US_emissions[data['Country Name'] == 'United States'].dropna(axis=1)
CO2_US_emissions = CO2_US_emissions.melt(id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
                   var_name='Year', value_name='CO2 emissions (kt)')

CO2_US_emissions.head()
# Out:
# C:\Users\princ\AppData\Local\Temp\ipykernel_3572\2977944980.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   CO2_US_emissions = CO2_US_emissions[data['Country Name'] == 'United States'].dropna(axis=1)
#     Country Name Country Code  \
# 0  United States          USA
# 1  United States          USA
# 2  United States          USA
# 3  United States          USA
# 4  United States          USA
#
#                                       Indicator Name     Indicator Code  Year  \
# 0  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE  1970
# 1  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE  1971
# 2  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE  1972
# 3  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE  1973
# 4  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE  1974
#
#    CO2 emissions (kt)
# 0          5400503.50
# 1          5440420.62
# 2          5704297.25
# 3          5912971.38
# 4          5756864.10

# %%
chart1 = alt.Chart(CO2_US_emissions).mark_line().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('CO2 emissions (kt):Q', title='CO2 emissions (kt)'),
).properties(
    title='Total Greenhouse Gas Emissions in the United States (kt of CO2 equivalent)',
    width=700,
    height=400
)

chart1.show()
# Out:
# alt.Chart(...)

# %%
forest_land = data[data['Indicator Code'] == 'AG.LND.FRST.K2']
forest_land = forest_land[forest_land['Country Name'] == 'United States'].dropna(axis=1)
forest_land = forest_land.melt(id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
                   var_name='Year', value_name='Forest_area')

forest_land.head()
# Out:
#     Country Name Country Code        Indicator Name  Indicator Code  Year  \
# 0  United States          USA  Forest area (sq. km)  AG.LND.FRST.K2  1990
# 1  United States          USA  Forest area (sq. km)  AG.LND.FRST.K2  1991
# 2  United States          USA  Forest area (sq. km)  AG.LND.FRST.K2  1992
# 3  United States          USA  Forest area (sq. km)  AG.LND.FRST.K2  1993
# 4  United States          USA  Forest area (sq. km)  AG.LND.FRST.K2  1994
#
#    Forest_area
# 0    3024500.0
# 1    3025586.0
# 2    3026672.0
# 3    3027758.0
# 4    3028844.0

# %%
chart2 = alt.Chart(forest_land).mark_line().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Forest_area:Q', title='Forest Area (sq. km)'),
).properties(
    title='Forest Area in the United States (sq. km)',
    width=700,
    height=400,
).configure_mark(
    color='green'
)

chart2.show()
# Out:
# alt.Chart(...)

# %% [markdown]
# I What is the trend of greenhouse gas emissions in different sectors (agriculture, industry, transport)?
# Which sectors contribute the most to CO₂ emissions over time?

# %%
#Create US_data DataFrame
US_data = data[data['Country Name'] == 'United States']

# Filter for CO2 emissions
CO2_US_data = US_data[
    (US_data['Indicator Code'] == 'EN.CO2.TRAN.ZS') |
    (US_data['Indicator Code'] == 'EN.CO2.OTHX.ZS') |
    (US_data['Indicator Code'] == 'EN.CO2.MANF.ZS') |
    (US_data['Indicator Code'] == 'EN.CO2.ETOT.ZS') |
    (US_data['Indicator Code'] == 'EN.CO2.BLDG.ZS')
].dropna(axis=1)
CO2_US_data = CO2_US_data.melt(id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
                   var_name='Year', value_name='CO2 emissions (% of total)')

CO2_US_data['Indicator Name'] = CO2_US_data['Indicator Name'].replace(
    {
        'CO2 emissions from transport (% of total fuel combustion)': 'Transportation',
        'CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)': 'Other Sectors',
        'CO2 emissions from manufacturing industries and construction (% of total fuel combustion)': 'Manufacturing',
        'CO2 emissions from electricity and heat production, total (% of total fuel combustion)': 'Electricity and Heat',
        'CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)': 'Residential Buildings, Commercial & public Services'
    }
)

CO2_US_data.head()
# Out:
#     Country Name Country Code  \
# 0  United States          USA
# 1  United States          USA
# 2  United States          USA
# 3  United States          USA
# 4  United States          USA
#
#                                       Indicator Name  Indicator Code  Year  \
# 0                                     Transportation  EN.CO2.TRAN.ZS  1960
# 1                                      Other Sectors  EN.CO2.OTHX.ZS  1960
# 2                                      Manufacturing  EN.CO2.MANF.ZS  1960
# 3                               Electricity and Heat  EN.CO2.ETOT.ZS  1960
# 4  Residential Buildings, Commercial & public Ser...  EN.CO2.BLDG.ZS  1960
#
#    CO2 emissions (% of total)
# 0                   23.731404
# 1                    1.908181
# 2                   27.184828
# 3                   27.635213
# 4                   19.540373

# %%
# Create a Stacked bar char for CO2 emissions by sector

sector_colors = {
    'Transportation': '#2ca02c',  # Green
    'Other Sectors': '#d62728',  # Red
    'Manufacturing': '#ff7f0e',  # Orange
    'Electricity and Heat': '#1f77b4',  # Blue
    'Residential Buildings, Commercial & public Services': '#17becf'  # Light Blue
}

options = list(sector_colors.keys())
labels = [option + ' ' for option in options]

input_radio = alt.binding_radio(
    options=options + [None],
    labels=labels + ['All'],
    name='Sector: '
)
selection = alt.selection_point(
    fields=['Indicator Name'], 
    bind=input_radio,
)

chart3 = alt.Chart(CO2_US_data).mark_bar().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('CO2 emissions (% of total)', title='CO2 emissions (% of total)', scale=alt.Scale(domain=[0, 100])),
    color=alt.Color(
        'Indicator Name',
        title='Sector',
        scale=alt.Scale(domain=list(sector_colors.keys()), range=list(sector_colors.values()))  # Set consistent colors
    ),
    tooltip=['Indicator Name:N', 'CO2 emissions (% of total)'],
).transform_filter(
    selection
).properties(
    title='CO2 Emissions by Sector in the United States (% of total)',
    width=700,
    height=400,
).configure_legend(
    labelLimit=0
).add_params(
    selection
)

chart3
# Out:
# alt.Chart(...)
